# %%
import pandas as pd
import numpy as np

# %%
# Text Preprocessing & Cleaning
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
import re

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\baljeet\anaconda3\lib\site-packages (1.8.2.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\baljeet\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\baljeet\anaconda3\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: pillow in c:\users\baljeet\anaconda3\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\baljeet\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\baljeet\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\baljeet\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\baljeet\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\baljeet\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\baljeet\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\baljeet\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
# !pip install termcolor
# Out:
# Requirement already satisfied: termcolor in c:\users\baljeet\anaconda3\lib\site-packages (2.0.1)

# %%
import matplotlib.pyplot as plt
from wordcloud import wordcloud
from termcolor import cprint
import seaborn as sns
import warnings

# %%
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Airline-Sentiment.csv', header= 0,
                        encoding= 'unicode_escape')

# %%
df.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  681448150    False   finalized                   3    2/25/2015 5:24
# 1  681448153    False   finalized                   3    2/25/2015 1:53
# 2  681448156    False   finalized                   3   2/25/2015 10:01
# 3  681448158    False   finalized                   3    2/25/2015 3:05
# 4  681448159    False   finalized                   3    2/25/2015 5:50
#
#   airline_sentiment  airline_sentiment:confidence negativereason  \
# 0           neutral                        1.0000            NaN
# 1          positive                        0.3486            NaN
# 2           neutral                        0.6837            NaN
# 3          negative                        1.0000     Bad Flight
# 4          negative                        1.0000     Can't Tell
#
#    negativereason:confidence         airline        name  retweet_count  \
# 0                        NaN  Virgin America     cairdin              0
# 1                     0.0000  Virgin America    jnardino              0
# 2                        NaN  Virgin America  yvonnalynn              0
# 3                     0.7033  Virgin America    jnardino              0
# 4                     1.0000  Virgin America    jnardino              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#      tweet_created      tweet_id tweet_location               user_timezone
# 0  2/24/2015 11:35  5.700000e+17            NaN  Eastern Time (US & Canada)
# 1  2/24/2015 11:15  5.700000e+17            NaN  Pacific Time (US & Canada)
# 2  2/24/2015 11:15  5.700000e+17      Lets Play  Central Time (US & Canada)
# 3  2/24/2015 11:15  5.700000e+17            NaN  Pacific Time (US & Canada)
# 4  2/24/2015 11:14  5.700000e+17            NaN  Pacific Time (US & Canada)

# %%
df.shape
# Out:
# (14640, 18)

# %%
positive = df[df['airline_sentiment'] == 'positive'].text
neutral  = df[df['airline_sentiment'] == 'neutral'].text
negative  = df[df['airline_sentiment'] == 'negative'].text

# %%
def convert_Sentiment(sentiment):
    if  sentiment == "positive":
        return 2
    elif sentiment == "neutral":
        return 1
    elif sentiment == "negative":
        return 0

# %%
df.airline_sentiment = df.airline_sentiment.apply(lambda x : convert_Sentiment(x))

# %%
df.airline_sentiment
# Out:
# 0        1
# 1        2
# 2        1
# 3        0
# 4        0
#         ..
# 14635    2
# 14636    0
# 14637    1
# 14638    0
# 14639    1
# Name: airline_sentiment, Length: 14640, dtype: int64

# %%
def remove_stopwords(text):
    text = ' '.join([word for word in text.split() if word not in (stopwords.words('english'))])
    return text
def remove_url(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'',text)
def remove_punct(text):
    table = str.maketrans('', '', string.punctuation)
    return text.translate(table)
def remove_html(text):
    html=re.compile(r'<.*?>')
    return html.sub(r'',text)
def remove_username(text):
    return re.sub('@[^\s]+','',text)
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
def decontraction(text):
    text = re.sub(r"won\'t", " will not", text)
    text = re.sub(r"won\'t've", " will not have", text)
    text = re.sub(r"can\'t", " can not", text)
    text = re.sub(r"don\'t", " do not", text)
    
    text = re.sub(r"can\'t've", " can not have", text)
    text = re.sub(r"ma\'am", " madam", text)
    text = re.sub(r"let\'s", " let us", text)
    text = re.sub(r"ain\'t", " am not", text)
    text = re.sub(r"shan\'t", " shall not", text)
    text = re.sub(r"sha\n't", " shall not", text)
    text = re.sub(r"o\'clock", " of the clock", text)
    text = re.sub(r"y\'all", " you all", text)
    text = re.sub(r"n\'t", " not", text)
    text = re.sub(r"n\'t've", " not have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'s", " is", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'d've", " would have", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ll've", " will have", text)
    text = re.sub(r"\'t", " not", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'m", " am", text)
    text = re.sub(r"\'re", " are", text)
    return text

# %%
def seperate_alphanumeric(text):
    words = text
    words = re.findall(r"[^\W\d_]+|\d+", words)
    return " ".join(words)
def cont_rep_char(text):
    tchr = text.group(0) 
    
    if len(tchr) > 1:
        return tchr[0:2] 
def unique_char(rep, text):
    substitute = re.sub(r'(\w)\1+', rep, text)
    return substitute
def char(text):
    substitute = re.sub(r'[^a-zA-Z]',' ',text)
    return substitute

# %%
df['final_text'] = df['negativereason'].fillna('') + ' ' + df['text']

# %%
from nltk.corpus import stopwords

# %%
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\BALJEET\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
df['final_text'] = df['final_text'].apply(lambda x : remove_username(x))
df['final_text'] = df['final_text'].apply(lambda x : remove_url(x))
df['final_text'] = df['final_text'].apply(lambda x : remove_emoji(x))
df['final_text'] = df['final_text'].apply(lambda x : decontraction(x))
df['final_text'] = df['final_text'].apply(lambda x : seperate_alphanumeric(x))
df['final_text'] = df['final_text'].apply(lambda x : unique_char(cont_rep_char,x))
df['final_text'] = df['final_text'].apply(lambda x : char(x))
df['final_text'] = df['final_text'].apply(lambda x : x.lower())
df['final_text'] = df['final_text'].apply(lambda x : remove_stopwords(x))

# %%
df['final_text']
# Out:
# 0                                                     said
# 1                  plus added commercials experience tacky
# 2                   today must mean need take another trip
# 3        bad flight really aggressive blast obnoxious e...
# 4                             ca tell really big bad thing
#                                ...
# 14635                   thank got different flight chicago
# 14636    customer service issue leaving minutes late fl...
# 14637            please bring american airlines blackberry
# 14638    customer service issue money change flight ans...
# 14639    ppl need know many seats next flight plz put u...
# Name: final_text, Length: 14640, dtype: object

# %%
review_df = df[['text','final_text','airline_sentiment']]

print(review_df.shape)
review_df.head(10)
# Out:
# (14640, 3)
#                                                 text  \
# 0                @VirginAmerica What @dhepburn said.
# 1  @VirginAmerica plus you've added commercials t...
# 2  @VirginAmerica I didn't today... Must mean I n...
# 3  @VirginAmerica it's really aggressive to blast...
# 4  @VirginAmerica and it's a really big bad thing...
# 5  @VirginAmerica seriously would pay $30 a fligh...
# 6  @VirginAmerica yes, nearly every time I fly VX...
# 7  @VirginAmerica Really missed a prime opportuni...
# 8  @virginamerica Well, I didn'tÛ_but NOW I DO! :-D
# 9  @VirginAmerica it was amazing, and arrived an ...
#
#                                           final_text  airline_sentiment
# 0                                               said                  1
# 1            plus added commercials experience tacky                  2
# 2             today must mean need take another trip                  1
# 3  bad flight really aggressive blast obnoxious e...                  0
# 4                       ca tell really big bad thing                  0
# 5  ca tell seriously would pay flight seats playi...                  0
# 6      yes nearly every time fly vx ear worm go away                  2
# 7  really missed prime opportunity men without ha...                  1
# 8                                               well                  2
# 9                    amazing arrived hour early good                  2

# %%
X = df['final_text']
y = df['airline_sentiment']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
X = df['final_text']
y = df['airline_sentiment']

# %%
tfidf = TfidfVectorizer()
X_final =  tfidf.fit_transform(X)

# %%
print(len(tfidf.vocabulary_))
# Out:
# 10986

# %%
tfidf.vocabulary_
# Out:
# {'said': 8282,
#  'plus': 7211,
#  'added': 123,
#  'commercials': 1864,
#  'experience': 3310,
#  'tacky': 9438,
#  'today': 9777,
#  'must': 6238,
#  'mean': 5874,
#  'need': 6314,
#  'take': 9454,
#  'another': 435,
#  'trip': 9942,
#  'bad': 768,
#  'flight': 3605,
#  'really': 7712,
#  'aggressive': 204,
#  'blast': 1048,
#  'obnoxious': 6602,
#  'entertainment': 3116,
#  'guests': 4193,
#  'faces': 3370,
#  'amp': 381,
#  'little': 5527,
#  'recourse': 7768,
#  'ca': 1354,
#  'tell': 9540,
#  'big': 986,
#  'thing': 9649,
#  'seriously': 8523,
#  'would': 10833,
#  'pay': 6982,
#  'seats': 8444,
#  'playing': 7179,
#  'flying': 3665,
#  'va': 10318,
#  'yes': 10913,
#  'nearly': 6310,
#  'every': 3219,
#  'time': 9736,
#  'fly': 3656,
#  'vx': 10464,
#  'ear': 2931,
#  'worm': 10807,
#  'go': 4038,
#  'away': 728,
#  'missed': 6066,
#  'prime': 7405,
#  'opportunity': 6724,
#  'men': 5930,
#  'without': 10750,
#  'hats': 4300,
#  'parody': 6916,
#  'well': 10601,
#  'amazing': 343,
#  'arrived': 572,
#  'hour': 4538,
#  'early': 2934,
#  'good': 4064,
#  'know': 5257,
#  'suicide': 9290,
#  'second': 8449,
#  'leading': 5377,
#  'cause': 1496,
#  'death': 2394,
#  'among': 376,
#  'teens': 9532,
#  'lt': 5670,
#  'pretty': 7382,
#  'graphics': 4121,
#  'much': 6215,
#  'better': 964,
#  'minimal': 6024,
#  'iconography': 4622,
#  'great': 4128,
#  'deal': 2386,
#  'already': 315,
#  'thinking': 9656,
#  'nd': 6305,
#  'even': 3205,
#  'gone': 4060,
#  'st': 9047,
#  'yet': 10918,
#  'fabulous': 3364,
#  'seductive': 8464,
#  'skies': 8742,
#  'stress': 9204,
#  'travel': 9898,
#  'thanks': 9601,
#  'late': 5338,
#  'sfo': 8556,
#  'pdx': 6995,
#  'schedule': 8384,
#  'still': 9139,
#  'mia': 5973,
#  'excited': 3259,
#  'first': 3557,
#  'cross': 2219,
#  'country': 2135,
#  'lax': 5361,
#  'mco': 5865,
#  'heard': 4329,
#  'nothing': 6531,
#  'things': 9651,
#  'virgin': 10418,
#  'america': 354,
#  'daystogo': 2374,
#  'flew': 3593,
#  'nyc': 6590,
#  'last': 5330,
#  'week': 10582,
#  'could': 2124,
#  'fully': 3865,
#  'sit': 8716,
#  'seat': 8437,
#  'due': 2902,
#  'two': 10032,
#  'large': 5324,
#  'gentleman': 3946,
#  'either': 2996,
#  'side': 8670,
#  'help': 4355,
#  'amazingly': 345,
#  'awesome': 731,
#  'bos': 1136,
#  'fll': 3640,
#  'please': 7186,
#  'want': 10513,
#  'fares': 3422,
#  'may': 5845,
#  'three': 9686,
#  'times': 9740,
#  'carriers': 1461,
#  'available': 702,
#  'select': 8483,
#  'love': 5645,
#  'graphic': 4120,
#  'hipster': 4412,
#  'innovation': 4841,
#  'feel': 3471,
#  'brand': 1178,
#  'making': 5755,
#  'gt': 4178,
#  'las': 5328,
#  'non': 6467,
#  'stop': 9165,
#  'permanently': 7044,
#  'anytime': 464,
#  'soon': 8910,
#  'customer': 2281,
#  'service': 8530,
#  'issue': 4999,
#  'guys': 4210,
#  'messed': 5953,
#  'seating': 8442,
#  'reserved': 7999,
#  'friends': 3812,
#  'gave': 3925,
#  'free': 3781,
#  'internet': 4922,
#  'status': 9099,
#  'match': 5836,
#  'program': 7466,
#  'applied': 503,
#  'weeks': 10588,
#  'called': 1384,
#  'emailed': 3027,
#  'response': 8020,
#  'happened': 4261,
#  'ur': 10264,
#  'vegan': 10359,
#  'food': 3703,
#  'options': 6733,
#  'least': 5390,
#  'say': 8352,
#  'site': 8717,
#  'able': 25,
#  'eat': 2955,
#  'anything': 463,
#  'next': 6385,
#  'hrs': 4557,
#  'fail': 3375,
#  'miss': 6065,
#  'worry': 10812,
#  'together': 9782,
#  'get': 3961,
#  'cold': 1806,
#  'air': 227,
#  'vents': 10372,
#  'noair': 6427,
#  'worstflightever': 10824,
#  'roasted': 8156,
#  'sfotobos': 8557,
#  'ewr': 3239,
#  'middle': 5982,
#  'red': 7779,
#  'eye': 3351,
#  'noob': 6483,
#  'maneuver': 5779,
#  'sendambien': 8500,
#  'andchexmix': 396,
#  'booking': 1116,
#  'problems': 7435,
#  'hi': 4387,
#  'bked': 1027,
#  'cool': 2085,
#  'birthday': 1010,
#  'add': 122,
#  'elevate': 3006,
#  'entered': 3109,
#  'name': 6265,
#  'hours': 4541,
#  'operation': 6716,
#  'club': 1761,
#  'posted': 7281,
#  'online': 6692,
#  'current': 2266,
#  'left': 5402,
#  'expensive': 3308,
#  'headphones': 4323,
#  'iad': 4607,
#  'one': 6679,
#  'answering': 441,
#  'number': 6573,
#  'awaiting': 723,
#  'return': 8065,
#  'phone': 7085,
#  'call': 1381,
#  'prefer': 7340,
#  'use': 10289,
#  'self': 8489,
#  'option': 6732,
#  'news': 6381,
#  'start': 9079,
#  'flights': 3630,
#  'hawaii': 4307,
#  'end': 3071,
#  'year': 10901,
#  'via': 10393,
#  'nice': 6394,
#  'rt': 8220,
#  'vibe': 10395,
#  'moodlight': 6152,
#  'takeoff': 9458,
#  'touchdown': 9837,
#  'moodlitmonday': 6154,
#  'sciencebehindtheexperience': 8396,
#  'moodlighting': 6153,
#  'way': 10553,
#  'best': 946,
#  'ever': 3216,
#  'calming': 1390,
#  'done': 2794,
#  'airline': 238,
#  'around': 563,
#  'hands': 4247,
#  'book': 1113,
#  'chat': 1592,
#  'support': 9326,
#  'working': 10799,
#  'view': 10405,
#  'downtown': 2840,
#  'los': 5616,
#  'angeles': 403,
#  'hollywood': 4453,
#  'sign': 8676,
#  'beyond': 972,
#  'rain': 7638,
#  'mountains': 6178,
#  'hey': 4382,
#  'flyer': 3660,
#  'hard': 4278,
#  'getting': 3977,
#  'account': 73,
#  'plz': 7212,
#  'win': 10712,
#  'bid': 985,
#  'upgrade': 10246,
#  'sea': 8428,
#  'unused': 10231,
#  'ticket': 9714,
#  'moved': 6183,
#  'new': 6366,
#  'city': 1692,
#  'expires': 3318,
#  'travelhelp': 9904,
#  'leaving': 5397,
#  'dallas': 2328,
#  'seattle': 8445,
#  'feb': 3458,
#  'elevategold': 3007,
#  'reason': 7717,
#  'rock': 8171,
#  'dream': 2861,
#  'wow': 10842,
#  'blew': 1059,
#  'mind': 6017,
#  'night': 6405,
#  'tribute': 9935,
#  'soundofmusic': 8929,
#  'oscars': 6767,
#  'think': 9654,
#  'agree': 209,
#  'entertaining': 3115,
#  'supposed': 9331,
#  'minutes': 6037,
#  'ago': 208,
#  'website': 10575,
#  'shows': 8651,
#  'julie': 5156,
#  'andrews': 399,
#  'though': 9672,
#  'impressive': 4708,
#  'wish': 10744,
#  'atlanta': 637,
#  'la': 5288,
#  'february': 3459,
#  'th': 9589,
#  'lga': 5444,
#  'dal': 2326,
#  'trying': 9980,
#  'since': 8699,
#  'page': 6873,
#  'never': 6352,
#  'loads': 5553,
#  'thx': 9707,
#  'spotify': 9017,
#  'stat': 9087,
#  'guiltypleasures': 4198,
#  'lady': 5301,
#  'gaga': 3898,
#  'carrie': 1458,
#  'marketing': 5808,
#  'song': 8906,
#  'let': 5425,
#  'us': 10270,
#  'meh': 5910,
#  'adding': 124,
#  'shown': 8650,
#  'carrieunderwood': 1462,
#  'sorry': 8914,
#  'mary': 5824,
#  'martin': 5822,
#  'beat': 881,
#  'classics': 1710,
#  'dca': 2378,
#  'pm': 7213,
#  'tried': 9940,
#  'check': 1606,
#  'heyy': 4384,
#  'guyys': 4211,
#  'someone': 8897,
#  'hold': 4438,
#  'earlier': 2932,
#  'tonight': 9807,
#  'congrats': 1983,
#  'winning': 10726,
#  'award': 725,
#  'deals': 2389,
#  'lost': 5623,
#  'luggage': 5681,
#  'everything': 3223,
#  'fine': 3541,
#  'bag': 787,
#  'change': 1556,
#  'reservation': 7996,
#  'credit': 2198,
#  'card': 1436,
#  'modify': 6116,
#  'waive': 10486,
#  'fee': 3468,
#  'team': 9515,
#  'tracking': 9858,
#  'booked': 1115,
#  'baggage': 790,
#  'attendant': 652,
#  'complaints': 1923,
#  'loft': 5574,
#  'needs': 6319,
#  'step': 9120,
#  'game': 3909,
#  'dirty': 2639,
#  'tables': 9434,
#  'floors': 3643,
#  'worried': 10809,
#  'ride': 8107,
#  'plane': 7154,
#  'crew': 2202,
#  'airlines': 241,
#  'like': 5480,
#  'yall': 10892,
#  'sat': 8324,
#  'morning': 6160,
#  'correct': 2101,
#  'bill': 994,
#  'watch': 10542,
#  'student': 9238,
#  'films': 3524,
#  'feet': 3480,
#  'cmfat': 1770,
#  'different': 2603,
#  'rate': 7668,
#  'policy': 7234,
#  'media': 5895,
#  'bags': 796,
#  'going': 4049,
#  'anyway': 465,
#  'speak': 8965,
#  'human': 4573,
#  'asap': 582,
#  'thank': 9593,
#  'doom': 2811,
#  'supp': 9323,
#  'biz': 1022,
#  'traveler': 9901,
#  'neverflyvirginforbusiness': 6360,
#  'member': 5921,
#  'inflight': 4815,
#  'im': 4675,
#  'interested': 4910,
#  'flightattendant': 3608,
#  'dreampath': 2864,
#  'whenever': 10651,
#  'begrudgingly': 911,
#  'delayed': 2453,
#  'interesting': 4911,
#  'cancelled': 1404,
#  'four': 3754,
#  'planned': 7160,
#  'disappointing': 2651,
#  'shared': 8580,
#  'business': 1325,
#  'meet': 5905,
#  'neverflyvirgin': 6359,
#  'trouble': 9954,
#  'wife': 10696,
#  'bring': 1219,
#  'using': 10300,
#  'code': 1795,
#  'random': 7651,
#  'distribution': 2736,
#  'avatars': 705,
#  'bet': 959,
#  'kitty': 5247,
#  'disproportionate': 2712,
#  'share': 8579,
#  'life': 5463,
#  'happens': 4263,
#  'jperhi': 5145,
#  'home': 4457,
#  'back': 754,
#  'rnp': 8149,
#  'yeah': 10900,
#  'points': 7226,
#  'recent': 7742,
#  'tv': 10012,
#  'video': 10402,
#  'disappointed': 2650,
#  'flightled': 3620,
#  'went': 10609,
#  'jfk': 5112,
#  'saturday': 8332,
#  'landed': 5312,
#  'friendly': 3807,
#  'nomorevirgin': 6466,
#  'redirected': 7789,
#  'btw': 1265,
#  'user': 10295,
#  'redesign': 7786,
#  'desktop': 2539,
#  'mobile': 6108,
#  'scanned': 8366,
#  'passengers': 6943,
#  'leave': 5395,
#  'told': 9790,
#  'remove': 7911,
#  'class': 1706,
#  'bin': 1000,
#  'uncomfortable': 10093,
#  'find': 3535,
#  'anyone': 460,
#  'useless': 10294,
#  'boy': 1161,
#  'prince': 7406,
#  'ressie': 8026,
#  'sf': 8555,
#  'thursday': 9705,
#  'appointments': 509,
#  'music': 6234,
#  'direct': 2628,
#  'unexpected': 10129,
#  'layover': 5364,
#  'vegas': 10360,
#  'fuel': 3857,
#  'peeps': 7009,
#  'bought': 1149,
#  'sneaky': 8846,
#  'apt': 532,
#  'people': 7023,
#  'exp': 3290,
#  'raeann': 7632,
#  'customerservice': 2286,
#  'virginamerica': 10419,
#  'line': 5499,
#  'hung': 4584,
#  'sarcasm': 8318,
#  'tripping': 9947,
#  'plain': 7149,
#  'text': 9580,
#  'version': 10384,
#  'reluctant': 7888,
#  'enter': 3108,
#  'info': 4817,
#  'scheduled': 8385,
#  'changed': 1557,
#  'weather': 10567,
#  'looks': 5609,
#  'getaway': 3962,
#  'lots': 5633,
#  'cities': 1689,
#  'cheapflights': 1600,
#  'farecompare': 3420,
#  'come': 1839,
#  'phl': 7079,
#  'horrible': 4510,
#  'pleasecomeback': 7187,
#  'concerned': 1947,
#  'tech': 9522,
#  'flown': 3648,
#  'easy': 2954,
#  'helpful': 4359,
#  'representatives': 7956,
#  'comfortable': 1849,
#  'rep': 7925,
#  'kicked': 5219,
#  'butt': 1335,
#  'naelah': 6260,
#  'represents': 7958,
#  'beautifully': 888,
#  'beautiful': 886,
#  'front': 3821,
#  'design': 2528,
#  'right': 8116,
#  'secure': 8459,
#  'running': 8251,
#  'gate': 3921,
#  'waited': 10476,
#  'kept': 5210,
#  'browser': 1247,
#  'reputation': 7963,
#  'built': 1285,
#  'compatible': 1900,
#  'totally': 9833,
#  'folks': 3695,
#  'problem': 7433,
#  'min': 6016,
#  'delay': 2452,
#  'connecting': 1993,
#  'seems': 8473,
#  'long': 5598,
#  'outstanding': 6804,
#  'san': 8301,
#  'francisco': 3765,
#  'absolute': 31,
#  'delighted': 2467,
#  'provide': 7513,
#  'complimentary': 1932,
#  'upgrades': 10249,
#  'thats': 9614,
#  'wait': 10475,
#  'calling': 1387,
#  'intern': 4917,
#  'completely': 1926,
#  'month': 6145,
#  'nonstop': 6478,
#  'depart': 2494,
#  'vabeatsjblue': 10319,
#  'failing': 3379,
#  'customers': 2285,
#  'process': 7444,
#  'link': 5506,
#  'tsa': 9985,
#  'pre': 7320,
#  'terrible': 9565,
#  'hotel': 4528,
#  'hotline': 4533,
#  'cabo': 1363,
#  'lucas': 5674,
#  'assistance': 611,
#  'yesterday': 10917,
#  'give': 4005,
#  'shame': 8571,
#  'likingyoulessandless': 5487,
#  'register': 7841,
#  'dog': 2781,
#  'dulles': 2907,
#  'queue': 7600,
#  'longer': 5600,
#  'pls': 7205,
#  'advise': 162,
#  'redcarpet': 7780,
#  'dropped': 2883,
#  'track': 9856,
#  'always': 331,
#  'xoxo': 10882,
#  'buy': 1338,
#  'creates': 2193,
#  'anxiety': 455,
#  'frustrated': 3831,
#  'paying': 6985,
#  'extra': 3342,
#  'bucks': 1270,
#  'might': 5991,
#  'afford': 181,
#  'hiring': 4418,
#  'hand': 4233,
#  'lame': 5308,
#  'world': 10804,
#  'irmafromdallas': 4971,
#  'takes': 9461,
#  'cake': 1372,
#  'flt': 3649,
#  'sooner': 8911,
#  'midnight': 5987,
#  'monday': 6127,
#  'cant': 1417,
#  'imagine': 4677,
#  'web': 10571,
#  'indicates': 4785,
#  'dude': 2901,
#  'staff': 9052,
#  'super': 9315,
#  'ran': 7650,
#  'princesshalf': 7409,
#  'spoiled': 9003,
#  'comfort': 1848,
#  'paid': 6876,
#  'premium': 7356,
#  'across': 99,
#  'offer': 6631,
#  'sad': 8269,
#  'face': 3365,
#  'question': 7598,
#  'possible': 7277,
#  'infant': 4805,
#  'giving': 4010,
#  'welcome': 10596,
#  'dc': 2377,
#  'sunset': 9313,
#  'globe': 4029,
#  'backtowinter': 764,
#  'work': 10790,
#  'refreshed': 7814,
#  'damaged': 2331,
#  'understand': 10109,
#  'dm': 2760,
#  'answer': 439,
#  'destroyed': 2553,
#  'special': 8969,
#  'alone': 312,
#  'kids': 5225,
#  'priority': 7418,
#  'boarding': 1090,
#  'checking': 1610,
#  'tickets': 9717,
#  'purchased': 7562,
#  'happy': 4267,
#  'coming': 1854,
#  'field': 3506,
#  'definitely': 2436,
#  'dfw': 2577,
#  'drivers': 2877,
#  'license': 5457,
#  'expired': 3317,
#  'friday': 3803,
#  'keeps': 5206,
#  'error': 3158,
#  'contact': 2030,
#  'minute': 6036,
#  'reschedule': 7981,
#  'button': 1336,
#  'greyed': 4147,
#  'rang': 7654,
#  'vendor': 10367,
#  'fix': 3569,
#  'got': 4084,
#  'checked': 1607,
#  'email': 3026,
#  'tomorrow': 9799,
#  'unacceptable': 10067,
#  'flighted': 3613,
#  'stuck': 9232,
#  'pairings': 6886,
#  'include': 4743,
#  'wine': 10719,
#  'white': 10672,
#  'offered': 6632,
#  'redwineisbetter': 7796,
#  'wonked': 10778,
#  'look': 5604,
#  'browsers': 1248,
#  'css': 2242,
#  'agent': 198,
#  'designated': 2529,
#  'silver': 8691,
#  'closed': 1744,
#  'assist': 610,
#  'pasengers': 6935,
#  'plans': 7163,
#  'austin': 685,
#  'route': 8202,
#  'topnews': 9819,
#  'arab': 536,
#  'emirates': 3046,
#  'normal': 6497,
#  'receive': 7738,
#  'reply': 7944,
#  'central': 1524,
#  'baggageissues': 793,
#  'smh': 8817,
#  'longlines': 5602,
#  'logan': 5577,
#  'airport': 246,
#  'waiting': 10478,
#  'checkin': 1609,
#  'desk': 2537,
#  'open': 6708,
#  'jump': 5158,
#  'market': 5807,
#  'beats': 884,
#  'eps': 3139,
#  'views': 10406,
#  'southwestair': 8939,
#  'luv': 5691,
#  'investor': 4948,
#  'daily': 2324,
#  'lister': 5519,
#  'show': 8646,
#  'begin': 908,
#  'april': 530,
#  'ketr': 5213,
#  'fuck': 3847,
#  'fl': 3578,
#  'clincher': 1737,
#  'follow': 3696,
#  'many': 5790,
#  'apologies': 475,
#  'worse': 10814,
#  'respond': 8016,
#  'cudtomers': 2253,
#  'spend': 8986,
#  'money': 6129,
#  'stranded': 9184,
#  'landing': 5313,
#  'reimburse': 7855,
#  'sjc': 8734,
#  'choice': 1659,
#  'southwest': 8938,
#  'days': 2369,
#  'confirmation': 1971,
#  'inquired': 4849,
#  'claim': 1696,
#  'notification': 6536,
#  'rebook': 7728,
#  'met': 5956,
#  'restr': 8033,
#  'gold': 4053,
#  'cmh': 1771,
#  'lot': 5632,
#  'thrown': 9698,
#  'see': 8465,
#  'worst': 10815,
#  'stuff': 9241,
#  'wrong': 10857,
#  'finding': 3538,
#  'missing': 6073,
#  'item': 5009,
#  'headed': 4318,
#  'americanairlines': 357,
#  'lose': 5617,
#  'suck': 9271,
#  'persisting': 7048,
#  'rec': 7734,
#  'flightlation': 3618,
#  'notice': 6533,
#  'ps': 7522,
#  'driving': 2879,
#  'mon': 6126,
#  'boston': 1140,
#  'stink': 9148,
#  'psp': 7527,
#  'ability': 24,
#  'expected': 3297,
#  'guy': 4208,
#  'dancing': 2341,
#  'high': 4393,
#  'school': 8391,
#  'dance': 2340,
#  'revue': 8091,
#  'quick': 7604,
#  'apparently': 488,
#  'faster': 3431,
#  'sitting': 8723,
#  'nervous': 6343,
#  'sent': 8508,
#  'picture': 7105,
#  'wing': 10720,
#  'keep': 5195,
#  'goodness': 4073,
#  'pressure': 7376,
#  'texas': 9578,
#  'beatstheothers': 885,
#  'crisis': 2212,
#  'ny': 6589,
#  'pilots': 7120,
#  'job': 5123,
#  'snow': 8851,
#  'york': 10925,
#  'area': 542,
#  'afternoon': 190,
#  'row': 8209,
#  'recline': 7752,
#  'mention': 5934,
#  'soreback': 8913,
#  'mechanical': 5889,
#  'handle': 4241,
#  'pros': 7503,
#  'tossed': 9829,
#  'drink': 2870,
#  'precipitation': 7331,
#  'scared': 8369,
#  'twitter': 10029,
#  'killed': 5227,
#  'rescheduling': 7985,
#  'charged': 1575,
#  'refusing': 7833,
#  'refund': 7823,
#  'access': 53,
#  'safari': 8274,
#  'iphone': 4964,
#  'mac': 5713,
#  'ipad': 4963,
#  'passbook': 6938,
#  'clicking': 1731,
#  'received': 7739,
#  'broken': 1235,
#  'header': 4319,
#  'elevateuser': 3008,
#  'numofpointsavailable': 6578,
#  'looking': 5608,
#  'forward': 3750,
#  'rescheduled': 7982,
#  'diehardvirgin': 2596,
#  'sec': 8448,
#  'gonna': 4062,
#  'land': 5311,
#  'cost': 2112,
#  'ugh': 10054,
#  'along': 313,
#  'subsequent': 9261,
#  'putting': 7576,
#  'bug': 1280,
#  'report': 7946,
#  'center': 1521,
#  'bit': 1015,
#  'nominated': 6462,
#  'meetthefleet': 5908,
#  'reset': 8000,
#  'password': 6952,
#  'arrives': 573,
#  'based': 845,
#  'silicon': 8688,
#  'valley': 10339,
#  'disruption': 2721,
#  'fcmostinnovative': 3451,
#  'incubator': 4772,
#  'nicely': 6395,
#  'watching': 10544,
#  'something': 8899,
#  'bubbly': 1267,
#  'departure': 2500,
#  'todays': 9778,
#  'palm': 6889,
#  'springs': 9027,
#  'hahaha': 4221,
#  'sounds': 8930,
#  'fun': 3866,
#  'updates': 10241,
#  'spruce': 9032,
#  'moose': 6157,
#  'unusable': 10230,
#  'count': 2126,
#  'somehow': 8896,
#  'classiq': 1711,
#  'greetingz': 4145,
#  'continues': 2053,
#  'helping': 4362,
#  'sorted': 8918,
#  'sweet': 9390,
#  'rockies': 8174,
#  'airplanemodewason': 244,
#  'blasting': 1049,
#  'sanfrancisco': 8307,
#  'iced': 4615,
#  'coffee': 1799,
#  'passenger': 6941,
#  'assaulted': 599,
#  'trust': 9971,
#  'banned': 827,
#  'filed': 3516,
#  'selecting': 8485,
#  'destination': 2548,
#  'severely': 8550,
#  'dented': 2487,
#  'wheel': 10645,
#  'miranda': 6041,
#  'itinerary': 5018,
#  'shift': 8599,
#  'impending': 4695,
#  'painless': 6881,
#  'girls': 4001,
#  'inspired': 4866,
#  'become': 894,
#  'woaw': 10767,
#  'event': 3211,
#  'march': 5795,
#  'abq': 29,
#  'vodkatonics': 10437,
#  'entire': 3118,
#  'expectations': 3296,
#  'shares': 8581,
#  'santa': 8312,
#  'cruz': 2232,
#  'sentinel': 8511,
#  'gratitude': 4126,
#  'mpower': 6195,
#  'werin': 10614,
#  'vipswagbags': 10416,
#  'avalonhollywood': 704,
#  'luxuries': 5701,
#  'aesthetics': 170,
#  'improve': 4710,
#  'requested': 7967,
#  'window': 10715,
#  'confirmed': 1973,
#  'treat': 9920,
#  'grand': 4106,
#  'budapest': 1271,
#  'oscarscountdown': 6768,
#  'wtf': 10864,
#  'purpose': 7567,
#  'exhausted': 3276,
#  'frequent': 3793,
#  'flier': 3601,
#  'inconvenience': 4758,
#  'full': 3863,
#  'boo': 1111,
#  'refunding': 7826,
#  'place': 7144,
#  'rise': 8133,
#  'financial': 3534,
#  'results': 8043,
#  'usa': 10271,
#  'adds': 134,
#  'pillows': 7118,
#  'instead': 4876,
#  'lie': 5459,
#  'flat': 3584,
#  'arms': 560,
#  'race': 7623,
#  'advantage': 155,
#  'mayweatherpacquiao': 5850,
#  'fight': 3510,
#  'makes': 5751,
#  'cutest': 2300,
#  'salt': 8294,
#  'pepper': 7025,
#  'shaker': 8565,
#  'cabin': 1358,
#  'behind': 917,
#  'selected': 8484,
#  'fav': 3441,
#  'hot': 4527,
#  'female': 3486,
#  'pilot': 7119,
#  'paris': 6910,
#  'surgery': 9347,
#  'doctor': 2775,
#  'contacted': 2031,
#  'charging': 1579,
#  'dress': 2867,
#  'suitcase': 9292,
#  'errors': 3161,
#  'past': 6953,
#  'ah': 214,
#  'order': 6740,
#  'regulation': 7851,
#  'atlantic': 638,
#  'benefits': 940,
#  'husband': 4599,
#  ...}

# %%
from flask import Flask, render_template, Response

# %%
response = tfidf.fit_transform(X)

# %%
print(response)
# Out:
#   (0, 8282)	1.0
#   (1, 9438)	0.5715144216199972
#   (1, 3310)	0.3059111495163962
#   (1, 1864)	0.4991825649009825
#   (1, 123)	0.4357510390241188
#   (1, 7211)	0.3751365529646431
#   (2, 9942)	0.36395420765197306
#   (2, 435)	0.34633875964424976
#   (2, 9454)	0.34712077682710796
#   (2, 6314)	0.29810885808388093
#   (2, 5874)	0.45320923958874404
#   (2, 6238)	0.48311623162963613
#   (2, 9777)	0.31531756249018034
#   (3, 7768)	0.34172941680948205
#   (3, 5527)	0.24745102976128194
#   (3, 381)	0.16193482755134644
#   (3, 3370)	0.35747511722056036
#   (3, 4193)	0.3488096329719864
#   (3, 3116)	0.28478615899228715
#   (3, 6602)	0.36864686945245756
#   (3, 1048)	0.36864686945245756
#   (3, 204)	0.35747511722056036
#   (3, 7712)	0.19007094309233563
#   (3, 3605)	0.07520299819101564
#   (3, 768)	0.154383894408021
#   :	:
#   (14637, 241)	0.3646003960065555
#   (14637, 7186)	0.28125266422116013
#   (14638, 9288)	0.4309101166888255
#   (14638, 1867)	0.4764689487768966
#   (14638, 7088)	0.3944599855576322
#   (14638, 5747)	0.2679196217307357
#   (14638, 6129)	0.33332527212766666
#   (14638, 439)	0.3261865602692411
#   (14638, 1556)	0.2691865900961429
#   (14638, 4999)	0.14216150587253423
#   (14638, 8530)	0.13722030790752698
#   (14638, 2281)	0.13971412093643185
#   (14638, 3605)	0.10672411443586682
#   (14639, 7574)	0.2663773902350274
#   (14639, 7300)	0.33872987181697317
#   (14639, 9069)	0.31425094279563076
#   (14639, 5790)	0.2809951981550399
#   (14639, 7023)	0.23424106940886333
#   (14639, 10270)	0.1925171368224531
#   (14639, 7212)	0.34526777368536193
#   (14639, 6385)	0.4869547731312384
#   (14639, 5257)	0.22321333079972824
#   (14639, 8444)	0.25169944946741046
#   (14639, 3605)	0.18329182642714156
#   (14639, 6314)	0.20384796477603298

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\baljeet\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\baljeet\anaconda3\lib\site-packages (from imblearn) (0.7.0)
# Requirement already satisfied: scikit-learn>=0.23 in c:\users\baljeet\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.1.3)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\baljeet\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.21.5)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\baljeet\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.9.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\baljeet\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\baljeet\anaconda3\lib\site-packages (from scikit-learn>=0.23->imbalanced-learn->imblearn) (2.2.0)

# %%
pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\baljeet\anaconda3\lib\site-packages (1.1.3)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\baljeet\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\baljeet\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\baljeet\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\baljeet\anaconda3\lib\site-packages (from scikit-learn) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE()
x_sm,y_sm = smote.fit_resample(X_final,y)

# %%
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.2, stratify=y_sm)

# %%
num_cls = len(np.unique(y_sm))

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\baljeet\anaconda3\lib\site-packages (2.10.0)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\baljeet\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (22.9.24)
# Requirement already satisfied: setuptools in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (63.4.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (1.50.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (0.27.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: packaging in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: numpy>=1.20 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (4.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\baljeet\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.28.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.3.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.13.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.0.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\baljeet\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\baljeet\anaconda3\lib\site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\baljeet\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\baljeet\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\baljeet\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\baljeet\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\baljeet\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\baljeet\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\baljeet\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\baljeet\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2022.9.14)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\baljeet\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\baljeet\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.2)

# %%
from keras.models import Model
from keras.layers import Flatten, Input, Dense, Activation
from keras.losses import BinaryCrossentropy
import numpy as np
import tensorflow as tf

from keras.utils.np_utils import to_categorical

from keras.activations import softmax, relu, sigmoid

# %%
y_train = to_categorical(y_train, num_classes=num_cls)
y_test = to_categorical(y_test, num_classes=num_cls)
X_train = X_train.toarray()
X_test = X_test.toarray()

# %%
sz = (X_train.shape[1])
num_h = 3000
I = Input(shape=(sz))
x = Dense(num_h)(I)
H = Activation("relu")(x)
x = Dense(num_cls)(H)
O = Activation("sigmoid")(x)
m1 = Model(inputs=I, outputs=H)
m1.compile(optimizer='rmsprop', loss=BinaryCrossentropy())
m2 = Model(inputs=I, outputs=O)
m2.compile(optimizer='rmsprop',loss=BinaryCrossentropy(), metrics=['accuracy'])

# %%
def elm(m1, m2, x_train, y_train, x_test, y_test):
    w_model = m2.get_weights()
    w_model1 = m1.get_weights()
    H = m1.predict(x_train)
    print(H.shape)
    w_model[0] = w_model1[0]
    w_model[1] = w_model1[1]
    w_model[2] = tf.matmul(tf.linalg.pinv(H),y_train)
    m2.set_weights(w_model)
    _, acc = m2.evaluate(x_test, y_test)
    return(m2, acc)

# %%
m2, test_acc = elm(m1, m2, X_train, y_train, X_test, y_test)
print(test_acc)
# Out:
# 689/689 [==============================] - 33s 48ms/step
# (22027, 3000)
# 173/173 [==============================] - 9s 47ms/step - loss: 0.6543 - accuracy: 0.8529
# 0.8529144525527954

# %%
m2.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10986)]           0
#
#  dense (Dense)               (None, 3000)              32961000
#
#  activation (Activation)     (None, 3000)              0
#
#  dense_1 (Dense)             (None, 3)                 9003
#
#  activation_1 (Activation)   (None, 3)                 0
#
# =================================================================
# Total params: 32,970,003
# Trainable params: 32,970,003
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_obt = m2.predict(X_test)
# Out:
# 173/173 [==============================] - 8s 47ms/step

# %%
def precision(label, confusion_matrix):
    tp = confusion_matrix[label, label];
    fn = np.sum(confusion_matrix[label, :]) - tp;
    fp = np.sum(confusion_matrix[:, label]) - tp;
    tn = np.sum(confusion_matrix) - (tp+fp+fn)
    return (tp)/(tp+fp)
    
def recall(label, confusion_matrix):
    tp = confusion_matrix[label, label];
    fn = np.sum(confusion_matrix[label, :]) - tp;
    fp = np.sum(confusion_matrix[:, label]) - tp;
    tn = np.sum(confusion_matrix) - (tp+fp+fn)
    return (tp)/(tp+fn)

def accuracy_f(label, confusion_matrix):
    tp = confusion_matrix[label, label];
    fn = np.sum(confusion_matrix[label, :]) - tp;
    fp = np.sum(confusion_matrix[:, label]) - tp;
    tn = np.sum(confusion_matrix) - (tp+fp+fn)
    return (tp+tn)/(tp+tn+fp+fn)
def tp_f(label, confusion_matrix):
    tp = confusion_matrix[label, label];
    fn = np.sum(confusion_matrix[label, :]) - tp;
    fp = np.sum(confusion_matrix[:, label]) - tp;
    tn = np.sum(confusion_matrix) - (tp+fp+fn)
    return tp,fn,fp,tn

# %%
y_obt.shape
# Out:
# (5507, 3)

# %%
y_test.shape
# Out:
# (5507, 3)

# %%
from sklearn.metrics import confusion_matrix, classification_report
y_obt_c = np.argmax(y_obt,axis=1)
y_test_c = np.argmax(y_test,axis=1)
conf = confusion_matrix(y_test_c.ravel() ,y_obt_c.ravel())
print('confusion matrix')
print('________________\n')
print(conf)
print('_______________________________________________________\n')
print(classification_report(y_test_c.ravel() ,y_obt_c.ravel()))
print('_______________________________________________________\n')
print("label     tp     fn     fp     tn   accuracy   precision   recall")
for label in range(num_cls):
    tp,fn,fp,tn = tp_f(label, conf.astype(float))
    print(f"{label+1:5d} {tp:6.0f} {fn:6.0f} {fp:6.0f} {tn:6.0f}   {accuracy_f(label, conf):8.3f}   {precision(label, conf):9.3f}   {recall(label, conf):6.3f}")
    
print('_______________________________________________________\n')    
acc=np.sum(np.diagonal(conf))/np.sum(conf)
print('Accuracy : {}'.format(acc))
# Out:
# confusion matrix
# ________________
#
# [[1706   92   38]
#  [ 103 1497  235]
#  [  65  277 1494]]
# _______________________________________________________
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92      1836
#            1       0.80      0.82      0.81      1835
#            2       0.85      0.81      0.83      1836
#
#     accuracy                           0.85      5507
#    macro avg       0.85      0.85      0.85      5507
# weighted avg       0.85      0.85      0.85      5507
#
# _______________________________________________________
#
# label     tp     fn     fp     tn   accuracy   precision   recall
#     1   1706    130    168   3503      0.946       0.910    0.929
#     2   1497    338    369   3303      0.872       0.802    0.816
#     3   1494    342    273   3398      0.888       0.846    0.814
# _______________________________________________________
#
# Accuracy : 0.8529144724895588

# %%
def elm_obj(m1, m2, pop_w, x_train, y_train, x_test, y_test):
    w_model = m2.get_weights()
    w_model1 = m1.get_weights()
    w_model1[0] = pop_w[0]
    w_model1[1] = pop_w[1]
    m1.set_weights(w_model1)
    H = m1.predict(x_train)
    w_model[0] = w_model1[0]
    w_model[1] = w_model1[1]
    w_model[2] = tf.matmul(tf.linalg.pinv(H),y_train)
    m2.set_weights(w_model)
    _, acc = m2.evaluate(x_test, y_test, verbose=False)
    return(m2, acc)

# %%
def get_model(sz, num_h):
    I = Input(shape=(sz))
    x = Dense(num_h)(I)
    H = Activation("sigmoid")(x)
    x = Dense(num_cls)(H)
    O = Activation("relu")(x)
    m1 = Model(inputs=I, outputs=H)
    m1.compile(optimizer='rmsprop', loss=BinaryCrossentropy())
    m2 = Model(inputs=I, outputs=O)
    m2.compile(optimizer='rmsprop',loss=BinaryCrossentropy(), metrics=['accuracy'])
    return(m1,m2)

# %%
m1, m2 = get_model(sz, num_h)

# %%
_, test_acc = elm_obj(m1, m2, m1.get_weights(), X_train, y_train, X_test, y_test)
# Out:
# 689/689 [==============================] - 34s 49ms/step

# %%
def zero_weight(w):
  for i in range(len(w)):
    w[i] = np.zeros(w[i].shape)
  return(w);
def get_random_deights(w):
  nw = np.copy(w)
  for i in range(len(w)):
    nw[i] = np.random.uniform(-1,1, w[i].shape)
  return(nw)
def get_random(w):
  nw = np.copy(w)
  for i in range(len(w)):
    nw[i] = np.random.random(w[i].shape)
  return(nw)
def scalar_mul(w,a):
  for i in range(len(w)):
    w[i]= np.multiply(w[i],a)
  return(w)
def scalar_sub(w, a):
  for i in range(len(w)):
    w[i]= w[i] - a
  return(w)
def vector_add(w, w1):
  for i in range(len(w)):
    w[i]= w[i] + w1[i]
  return(w)
def vector_sub(w, w1):
  for i in range(len(w)):
    w[i]= w[i] - w1[i]
  return(w)
def vector_mul(w, w1): 
  for i in range(len(w)):
    w[i]= np.multiply(w[i],w1[i])
  return(w)
def w_abs(w):
  for i in range(len(w)):
    w[i]= abs(w[i])
  return(w)

# %%
def ELM_GWO(m1, m2, X_train, y_train, X_test, y_test, SearchAgents_no,Max_iter):
    sz = (X_train.shape[1])
    num_h = 3000
    m1, m2 = get_model(sz, num_h)
    w = m1.get_weights()
    # initialize alpha, beta, and delta_pos
    Alpha_pos=zero_weight(w)
    Alpha_score=-1
    
    Beta_pos=zero_weight(w)
    Beta_score=-1
    
    Delta_pos=zero_weight(w)
    Delta_score=-1
    
    #Initialize the positions of search agents
    Positions = []
    
    for i in range(SearchAgents_no):
        Positions.append(get_random_deights(w))
    
    Convergence_curve=np.zeros(Max_iter)  

    # Main loop
    for l in range(0,Max_iter):
        print(l)
        for i in range(0,SearchAgents_no):
            # Calculate objective function for each search agent
            _,fitness=elm_obj(m1, m2, Positions[i], X_train, y_train, X_test, y_test)

            # Update Alpha, Beta, and Delta
            if fitness>Alpha_score :
                Alpha_score=fitness; # Update alpha
                Alpha_pos=Positions[i]
            
            
            if (fitness<Alpha_score and fitness>Beta_score ):
                Beta_score=fitness  # Update beta
                Beta_pos=Positions[i]
            
            
            if (fitness<Alpha_score and fitness<Beta_score and fitness>Delta_score): 
                Delta_score=fitness # Update delta
                Delta_pos=Positions[i]
        
        a=2-l*((2)/Max_iter); # a decreases linearly fron 2 to 0
        
        # Update the Position of search agents including omegas
        for i in range(0,SearchAgents_no):
            r1 = get_random(w)
            r2 = get_random(w)
            A1=scalar_sub(scalar_mul(r1, 2*a),a); # Equation (3.3)
            C1=scalar_mul(r2,2); # Equation (3.4)
            D_alpha=w_abs(vector_sub(vector_mul(C1,Alpha_pos),Positions[i])); # Equation (3.5)-part 1
            X1=vector_sub(Alpha_pos,vector_mul(A1,D_alpha)); # Equation (3.6)-part 1

            r1 = get_random(w)
            r2 = get_random(w)
            A2=scalar_sub(scalar_mul(r1, 2*a),a); # Equation (3.3)
            C2=scalar_mul(r2,2); # Equation (3.4)
            D_beta=w_abs(vector_sub(vector_mul(C2,Beta_pos),Positions[i]));
            X2=vector_sub(Beta_pos,vector_mul(A2,D_beta)); 


            r1 = get_random(w)
            r2 = get_random(w)
            A3=scalar_sub(scalar_mul(r1, 2*a),a); # Equation (3.3)
            C3=scalar_mul(r2,2); # Equation (3.4)
            D_delta=w_abs(vector_sub(vector_mul(C3,Delta_pos),Positions[i]));
            X3=vector_sub(Delta_pos,vector_mul(A3,D_delta)); 

            Positions[i]=np.copy(scalar_mul(vector_add(X1,vector_add(X2,X3)), 1.0/3.0));
                                        
        Convergence_curve[l]=Alpha_score;
        n = gc.collect()

        #if (l%1==0):
               #print(['At iteration '+ str(l)+ ' the best fitness is '+ str(Alpha_score)]);
    
    print(Convergence_curve)
    return Alpha_pos,Convergence_curve, m1,m2;

# %%
Max_iter=20
SearchAgents_no=3

# %%
import gc

# %%
Alpha_pos,Convergence_curve, m1,m2 = ELM_GWO(m1, m2, X_train, y_train, X_test, y_test, SearchAgents_no,Max_iter)
# Out:
# 0
# 689/689 [==============================] - 34s 49ms/step
# 689/689 [==============================] - 33s 48ms/step
# 689/689 [==============================] - 33s 47ms/step
# 1
# 689/689 [==============================] - 37s 53ms/step
# 689/689 [==============================] - 33s 48ms/step
# 689/689 [==============================] - 34s 50ms/step
# 2
# 689/689 [==============================] - 36s 51ms/step
# 689/689 [==============================] - 34s 50ms/step
# 689/689 [==============================] - 35s 51ms/step
# 3
# 689/689 [==============================] - 43s 60ms/step
# 689/689 [==============================] - 40s 58ms/step
# 689/689 [==============================] - 35s 50ms/step
# 4
# 689/689 [==============================] - 38s 53ms/step
# 689/689 [==============================] - 35s 50ms/step
# 689/689 [==============================] - 34s 50ms/step
# 5
# 689/689 [==============================] - 39s 55ms/step
# 689/689 [==============================] - 38s 49ms/step
# 689/689 [==============================] - 33s 48ms/step
# 6
# 689/689 [==============================] - 37s 54ms/step
# 689/689 [==============================] - 35s 51ms/step
# 689/689 [==============================] - 34s 50ms/step
# 7
# 689/689 [==============================] - 38s 54ms/step
# 689/689 [==============================] - 35s 50ms/step
# 689/689 [==============================] - 35s 51ms/step
# 8
# 689/689 [==============================] - 39s 54ms/step
# 689/689 [==============================] - 37s 51ms/step
# 689/689 [==============================] - 33s 48ms/step
# 9
# 689/689 [==============================] - 40s 58ms/step
# 689/689 [==============================] - 35s 51ms/step
# 689/689 [==============================] - 32s 47ms/step
# 10
# 689/689 [==============================] - 42s 59ms/step
# 689/689 [==============================] - 33s 47ms/step
# 689/689 [==============================] - 33s 48ms/step
# 11
# 689/689 [==============================] - 37s 52ms/step
# 689/689 [==============================] - 32s 47ms/step
# 689/689 [==============================] - 32s 45ms/step
# 12
# 689/689 [==============================] - 36s 51ms/step
# 689/689 [==============================] - 407s 592ms/step
# 689/689 [==============================] - 34s 48ms/step
# 13
# 689/689 [==============================] - 42s 59ms/step
# 689/689 [==============================] - 35s 51ms/step
# 689/689 [==============================] - 35s 50ms/step
# 14
# 689/689 [==============================] - 39s 53ms/step
# 689/689 [==============================] - 33s 48ms/step
# 689/689 [==============================] - 38s 52ms/step
# 15
# 689/689 [==============================] - 37s 53ms/step
# 689/689 [==============================] - 34s 49ms/step
# 689/689 [==============================] - 34s 49ms/step
# 16
# 689/689 [==============================] - 42s 60ms/step
# 689/689 [==============================] - 35s 51ms/step
# 689/689 [==============================] - 35s 50ms/step
# 17
# 689/689 [==============================] - 39s 56ms/step
# 689/689 [==============================] - 34s 50ms/step
# 689/689 [==============================] - 35s 51ms/step
# 18
# 689/689 [==============================] - 46s 65ms/step
# 689/689 [==============================] - 36s 52ms/step
# 689/689 [==============================] - 36s 52ms/step
# 19
# 689/689 [==============================] - 46s 62ms/step
# 689/689 [==============================] - 36s 51ms/step
# 689/689 [==============================] - 35s 50ms/step
# [0.47212639 0.75703651 0.80152535 0.8242237  0.83402944 0.83639008
#  0.8402034  0.8427456  0.8427456  0.8427456  0.8443799  0.84728527
#  0.84728527 0.84728527 0.84728527 0.84728527 0.84728527 0.84728527
#  0.84728527 0.84728527]
